# %% [markdown]
# <a href="https://colab.research.google.com/github/skyzoo1208/mat2lat2/blob/main/Kelvin_Alfarezy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
a=np.array ([[2,4,2],[3,1,1]])
b=np.array ([[3,1,1],[0,0,2]])
print (a+b)
# Out:
# [[5 5 3]
#  [3 1 3]]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.array([2,3,1,5,0,4])
y=np.array([2,4,7,3,0,1])
plt.plot(x,y)
plt.show()
