# %% [markdown]
# <a href="https://colab.research.google.com/github/skyzoo1208/mat2lat2/blob/main/mat2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.array([1,3,4,7,8,9])
y=np.array([2,3,4,6,7,10])
plt.plot(x,y,marker='o')
plt.title("PT TELKOMSEL")
plt.xlabel("Penjualan")
plt.ylabel("Tahun")
plt.show()
