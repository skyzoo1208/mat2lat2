# %% [markdown]
# <a href="https://colab.research.google.com/github/skyzoo1208/mat2lat2/blob/main/datareading%26cleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
latih=pd.read_csv('train.csv')
kosong_lat=latih.isnull().sum()
kosong_lat.to_frame('count')
# Out:
#              count
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2

# %%
uji=pd.read_csv('test.csv')
kosong_uji=uji.isnull().sum()
kosong_uji.to_frame('count')
# Out:
#              count
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0

# %%
latih.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
latih.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
latih.head()
# Out:
#    Survived  Pclass Sex   Age  SibSp  Parch
# 0         0       3   1  22.0      1      0
# 1         1       1   0  38.0      1      0
# 2         1       3   0  26.0      0      0
# 3         1       1   0  35.0      1      0
# 4         0       3   1  35.0      0      0

# %%
#-- Merubah male menjadi 1 atau pria --
latih.loc[latih['Sex']=='male','Sex'] = 1
#-- Merubah Female menjadi 0 atau wanita --
latih.loc[latih['Sex']=='female','Sex'] = 0

# %%
#-- melihat data latih yang Survived (selamat)
latih['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
fig, ax = plt.subplots(figsize=(2, 2))
#-- data adalah nama_file, x adalah field --
sns.countplot(data=latih, x='Survived', ax=ax)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
sns.displot(latih['Survived'], kde=True)

# %%
sns.displot(latih['Age'], kde=True)

# %%
latih.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Cabin       687
# dtype: int64

# %%
#latih.drop('Cabin', axis=1, inplace=True)
latih['Age'].fillna(latih['Age'].mean(), inplace=True)

# %%
latih.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# dtype: int64
